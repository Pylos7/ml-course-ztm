# %% [markdown]
# # 1. Introduction to Matplotlib

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1, 2, 3, 4]);

# %%
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
plt.plot(x, y);

# %% [markdown]
# ### 1st Method

# %%
fig = plt.figure() # Creates a figure
ax = fig.add_subplot() # Adds some axes
plt.show()

# %% [markdown]
# ### 2nd Method

# %%
fig = plt.figure() # Creates a figure
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y) # Add some data
plt.show();

# %% [markdown]
# ### 3rd Recomended Method

# %%
fig, ax = plt.subplots()
ax.plot(x, [50, 100, 200, 250]); # Add some data
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# # 2. Anatomy of a Matplotlib Figure

# %% [markdown]
# ### Example Workflow

# %%
# 0. Import matplotlib
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2. Setup plot
fig, ax = plt.subplots(figsize=(10, 10))

# 3. Plot data
ax.plot(x, y)

# 4. Customize plot
ax.set(title="Sample Plot",
       xlabel="x-axis",
       ylabel="y-axis")

# 5. Save & show (you save the whole figure)
fig.savefig("../images/sample-plot.png")

# %% [markdown]
# ### Example Workflow 2 (NumPy arrays)

# %%
# 0. Import matplotlib and numpy
import matplotlib.pyplot as plt
import numpy as np

# 1. Prepare data
x = np.linspace(0, 10, 100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# 2. Setup plot
fig, ax = plt.subplots(figsize=(5, 5))

# 3. Plot data
ax.plot(x, x**2);

# %% [markdown]
# # 3. Scatter Plot And Bar Plot

# %%
fix, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %%
# Make a plot from dictionary
nut_butter_prices = {"Almond Butter": 10,
                     "Peanut Butter": 8,
                     "Cashew Butter": 12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax.set(title="Dan's Nut Butter Store",
       ylabel="Price ($)");

# %%
car_sales = {"Toyota": 23,
             "Nissan": 12,
             "Tesla": 34,
             "Aston Martin": 7}
fig, ax = plt.subplots()
ax.barh(list(car_sales.keys()), list(car_sales.values()));

# %%
# Make some data
x = np.random.randn(1000)

# %%
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ### Two options for subplots

# %%
# Subplots option 1
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(ncols=2,
                                             nrows=2,
                                             figsize=(10, 5))
ax1.plot(x, x/2)
ax2.scatter(np.random.random(10), np.random.random(10))
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax4.hist(np.random.randn(1000));

# %%
# Subplots option 2
fig, ax = plt.subplots(nrows=2,
                       ncols=2,
                       figsize=(10, 5))
# Plot to each different index
ax[0, 0].plot(x, x/2)
ax[0, 1].scatter(np.random.random(10), np.random.random(10))
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax[1, 1].hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting from pandas DataFrames

# %%
import pandas as pd

# %%
# Make DataFrame
car_sales = pd.read_csv("../Pandas/car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range("1/1/2024", periods=1000))
ts = ts.cumsum()
ts.plot();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace("[\,\.\$]", '')
car_sales
# Out:
# C:\Users\Nestor\AppData\Local\Temp\ipykernel_6904\98079443.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace("[\,\.\$]", '')
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"] = pd.date_range("1/1/2024", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2024-01-01
# 1   Honda    Red          87899      4   5000 2024-01-02
# 2  Toyota   Blue          32549      3   7000 2024-01-03
# 3     BMW  Black          11179      5  22000 2024-01-04
# 4  Nissan  White         213095      4   3500 2024-01-05
# 5  Toyota  Green          99213      4   4500 2024-01-06
# 6   Honda   Blue          45698      4   7500 2024-01-07
# 7   Honda   Blue          54738      4   7000 2024-01-08
# 8  Toyota  White          60000      4   6250 2024-01-09
# 9  Nissan  White          31600      4   9700 2024-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2024-01-01         4000
# 1   Honda    Red          87899      4   5000 2024-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2024-01-03        16000
# 3     BMW  Black          11179      5  22000 2024-01-04        38000
# 4  Nissan  White         213095      4   3500 2024-01-05        41500
# 5  Toyota  Green          99213      4   4500 2024-01-06        46000
# 6   Honda   Blue          45698      4   7500 2024-01-07        53500
# 7   Honda   Blue          54738      4   7000 2024-01-08        60500
# 8  Toyota  White          60000      4   6250 2024-01-09        66750
# 9  Nissan  White          31600      4   9700 2024-01-10        76450

# %%
# Let's plot the total sales
car_sales.plot(x="Sale Date", y="Total Sales");

# %%
# Reassign Price column as a numeric column
car_sales["Price"] = car_sales["Price"].astype(int)

# Plot scatter plot with price column as numeric
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter")

# %%
# How about a bar graph
x = np.random.rand(10, 4)
x
# Out:
# array([[0.83922212, 0.26211352, 0.13540615, 0.362489  ],
#        [0.67746975, 0.15671607, 0.79613997, 0.79383665],
#        [0.45779923, 0.69524584, 0.01465307, 0.66399502],
#        [0.99198295, 0.07858761, 0.52526075, 0.94359722],
#        [0.6120067 , 0.66538307, 0.66805498, 0.1497039 ],
#        [0.86410988, 0.49558837, 0.36199292, 0.11152301],
#        [0.56729818, 0.72146852, 0.60073756, 0.47556862],
#        [0.96979024, 0.04523985, 0.47807603, 0.2448124 ],
#        [0.59233342, 0.04950095, 0.84096585, 0.45344995],
#        [0.23924879, 0.66528381, 0.94298804, 0.20761888]])

# %%
# Turn it into a dataframe

df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.839222  0.262114  0.135406  0.362489
# 1  0.677470  0.156716  0.796140  0.793837
# 2  0.457799  0.695246  0.014653  0.663995
# 3  0.991983  0.078588  0.525261  0.943597
# 4  0.612007  0.665383  0.668055  0.149704
# 5  0.864110  0.495588  0.361993  0.111523
# 6  0.567298  0.721469  0.600738  0.475569
# 7  0.969790  0.045240  0.478076  0.244812
# 8  0.592333  0.049501  0.840966  0.453450
# 9  0.239249  0.665284  0.942988  0.207619

# %%
df.plot.bar();

# %%
df.plot(kind="bar");

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2024-01-01         4000
# 1   Honda    Red          87899      4   5000 2024-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2024-01-03        16000
# 3     BMW  Black          11179      5  22000 2024-01-04        38000
# 4  Nissan  White         213095      4   3500 2024-01-05        41500
# 5  Toyota  Green          99213      4   4500 2024-01-06        46000
# 6   Honda   Blue          45698      4   7500 2024-01-07        53500
# 7   Honda   Blue          54738      4   7000 2024-01-08        60500
# 8  Toyota  White          60000      4   6250 2024-01-09        66750
# 9  Nissan  White          31600      4   9700 2024-01-10        76450

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar");

# %%
# How about histograms

car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
car_sales["Odometer (KM)"].plot.hist(bins=20)

# %%
car_sales.plot(x="Make", y="Odometer (KM)")

# %%
type(car_sales.groupby("Make").sum(numeric_only=True)["Price"].plot(kind="bar"))
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %% [markdown]
# ## Plotting from Pandas DataFrames 4

# %%
heart_disease = pd.read_csv("../Data/heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease["age"].plot.hist();

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(subplots=True, figsize=(10, 30));

# %% [markdown]
# # 4. Recomended OO Plotting Method

# %%
over50 = heart_disease[heart_disease["age"] > 50]
over50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# Pyplot Method
over50.plot(kind="scatter",
            x="age",
            y="chol",
            c="target");

# %%
# OO Method
fig, ax = plt.subplots(figsize=(10, 6))
over50.plot(kind="scatter",
            x="age",
            y="chol",
            c="target",
            ax=ax)
# ax.set_xlim([45, 100]);

# %% [markdown]
# ## Prefered OO Method from Scratch

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data points
scatter = ax.scatter(x=over50["age"],
                     y=over50["chol"],
                     c=over50["target"])

# Customize the plot
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol")

# Create custom legend handles and labels based on unique target values
unique_targets = over50["target"].unique()
legend_handles = [mpatches.Circle((0,0), color=scatter.cmap(scatter.norm(target))) for target in unique_targets]
legend_labels = ["No Disease" if target == 0 else "Disease" for target in unique_targets]

# Add legend
ax.legend(legend_handles, legend_labels, title="Target")

# Add a horizontal line
ax.axhline(over50["chol"].mean(),
          linestyle="--")

# Show the plot
plt.show()

# %%
over_50 = over50
over_
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Subplot of chol, age, thalach
fig, (ax0, ax1) = plt.subplots(nrows=2,
                               ncols=1,
                               figsize=(10, 10),
                              sharex=True)


# ax0
scatter = ax0.scatter(x=over_50["age"],
                      y=over_50["chol"],
                      c=over_50["target"])
# Customize
ax0.set(title="Heart Disease and Cholesterol Levels",
        xlabel="Age",
        ylabel="Cholesterol")
# Create custom legend handles and labels based on unique target values
unique_targets = over_50["target"].unique()
legend_handles = [mpatches.Circle((0,0), color=scatter.cmap(scatter.norm(target))) for target in unique_targets]
legend_labels = ["No Disease" if target == 0 else "Disease" for target in unique_targets]
# Add legend to ax0
ax0.legend(legend_handles, legend_labels, title="Target")
# Add hline
ax0.axhline(over_50["chol"].mean(),
            linestyle="--")

# ax1
scatter2 = ax1.scatter(x=over_50["age"],
                       y=over_50["thalach"],
                       c=over_50["target"])
# Customize
ax1.set(title="Heart Disease and Max Heart Rate",
        xlabel="Age",
        ylabel="Max Heart Rate")
# Create custom legend handles and labels based on unique target values
unique_targets = over_50["target"].unique()
legend_handles = [mpatches.Circle((0,0), color=scatter.cmap(scatter.norm(target))) for target in unique_targets]
legend_labels = ["No Disease" if target == 0 else "Disease" for target in unique_targets]
# Add legend to ax0
ax1.legend(legend_handles, legend_labels, title="Target")
# Add hline
ax1.axhline(over_50["thalach"].mean(),
           linestyle="--")
ax1.axhline(over_50["thalach"].mean(),
           linestyle="--")
# Add a title to the figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold")
# Plot
plt.show();

# %%
## Customizing matplotlib plots and getting stylish
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2024-01-01         4000
# 1   Honda    Red          87899      4   5000 2024-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2024-01-03        16000
# 3     BMW  Black          11179      5  22000 2024-01-04        38000
# 4  Nissan  White         213095      4   3500 2024-01-05        41500

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn-whitegrid')

# %%
car_sales["Price"].plot();

# %%
plt.style.use("seaborn")

# %%
car_sales["Price"].plot();

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
plt.style.use("ggplot")

# %%
car_sales["Price"].plot();

# %%
# Create some data
x = np.random.randn(10, 4)
x
# Out:
# array([[ 0.54904195, -0.29021139,  1.38917787,  0.03250058],
#        [ 0.30462076,  2.14794574,  0.13729163,  0.32508674],
#        [-0.08132826,  0.8479706 ,  1.6489195 ,  0.27373953],
#        [-0.39207392, -0.71774116, -0.80524274, -0.62810795],
#        [-0.42633806, -1.45977808, -0.09827595, -2.28089961],
#        [ 0.09661591, -0.21298874, -1.33161913, -0.70623304],
#        [ 0.07785748,  0.16370117, -0.06319109,  0.75042163],
#        [ 0.13756695,  0.69686727,  2.17737848, -0.31960182],
#        [ 1.16507726,  1.53247253,  1.90258114,  0.65711118],
#        [-0.89758885, -0.84023517,  1.64690198,  3.66585216]])

# %%
df = pd.DataFrame(x, columns=["a", "b", "c", "d"])
df
# Out:
#           a         b         c         d
# 0  0.549042 -0.290211  1.389178  0.032501
# 1  0.304621  2.147946  0.137292  0.325087
# 2 -0.081328  0.847971  1.648920  0.273740
# 3 -0.392074 -0.717741 -0.805243 -0.628108
# 4 -0.426338 -1.459778 -0.098276 -2.280900
# 5  0.096616 -0.212989 -1.331619 -0.706233
# 6  0.077857  0.163701 -0.063191  0.750422
# 7  0.137567  0.696867  2.177378 -0.319602
# 8  1.165077  1.532473  1.902581  0.657111
# 9 -0.897589 -0.840235  1.646902  3.665852

# %%
ax = df.plot(kind="bar")
ax

# %%
plt.style.use("seaborn-whitegrid")
# Customize out plot with the set() method
ax = df.plot(kind="bar")
# Add some labels and a title
ax.set(title="Random Number Bar Graph from DataFrame",
       xlabel="Row number",
       ylabel="Random number")
# Make the legend visible
ax.legend().set_visible(True)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Reset the style
plt.style.use("seaborn-whitegrid")

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data points
scatter = ax.scatter(x=over50["age"],
                     y=over50["chol"],
                     c=over50["target"],
                    cmap="winter") # This changes the color scheme

# Customize the plot
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol")

# Change limits
ax.set_xlim([45, 80])

# Create custom legend handles and labels based on unique target values
unique_targets = over50["target"].unique()
legend_handles = [mpatches.Circle((0,0), color=scatter.cmap(scatter.norm(target))) for target in unique_targets]
legend_labels = ["No Disease" if target == 0 else "Disease" for target in unique_targets]

# Add legend
ax.legend(legend_handles, legend_labels, title="Target")

# Add a horizontal line
ax.axhline(over50["chol"].mean(),
          linestyle="--")

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Subplot of chol, age, thalach
fig, (ax0, ax1) = plt.subplots(nrows=2,
                               ncols=1,
                               figsize=(10, 10),
                               sharex=True,)


# ax0
scatter = ax0.scatter(x=over_50["age"],
                      y=over_50["chol"],
                      c=over_50["target"],
                      cmap="winter")
# Customize
ax0.set(title="Heart Disease and Cholesterol Levels",
        xlabel="Age",
        ylabel="Cholesterol")
ax0.set_xlim([50, 80])
ax0.set_ylim([100, 600])
# Create custom legend handles and labels based on unique target values
unique_targets = over_50["target"].unique()
legend_handles = [mpatches.Circle((0,0), color=scatter.cmap(scatter.norm(target))) for target in unique_targets]
legend_labels = ["No Disease" if target == 0 else "Disease" for target in unique_targets]
# Add legend to ax0
ax0.legend(legend_handles, legend_labels, title="Target")
# Add hline
ax0.axhline(over_50["chol"].mean(),
            linestyle="--")

# ax1
scatter2 = ax1.scatter(x=over_50["age"],
                       y=over_50["thalach"],
                       c=over_50["target"],
                       cmap="winter")
# Customize
ax1.set(title="Heart Disease and Max Heart Rate",
        xlabel="Age",
        ylabel="Max Heart Rate")
ax1.set_xlim([50, 80])
ax1.set_ylim([60, 200])
# Create custom legend handles and labels based on unique target values
unique_targets = over_50["target"].unique()
legend_handles = [mpatches.Circle((0,0), color=scatter.cmap(scatter.norm(target))) for target in unique_targets]
legend_labels = ["No Disease" if target == 0 else "Disease" for target in unique_targets]
# Add legend to ax0
ax1.legend(legend_handles, legend_labels, title="Target")
# Find average hr disease and non disease
avg_hr_d = over_50[over_50["target"] == 1]["thalach"].mean()
avg_hr_nd = over_50[over_50["target"] == 0]["thalach"].mean()
# Add hlines
ax1.axhline(avg_hr_d,
            color="green",
            linestyle="--")
ax1.axhline(avg_hr_nd,
            color="blue",
            linestyle="--")
# Add a title to the figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold")
# Plot
plt.show();

# %%
fig.savefig("heart-disease-analysis-saved-with-code.png")
